# %%
from pathlib import Path

import pandas as pd

# Same address you pass to download_account_activity.py --wallet
WALLET_ADDRESS = "0x03fe8c5740b6624ba50d3480176ed7239a22b465"

_cwd = Path.cwd()
if (_cwd / "data").is_dir():
    DATA_DIR = _cwd / "data"
else:
    DATA_DIR = _cwd / "apps" / "insider_trades" / "data"

path = DATA_DIR / f"wallet_{WALLET_ADDRESS}.parquet"
df = pd.read_parquet(path)
df.head()
# Out:
#                                   proxyWallet   timestamp  \
# 0  0x03fe8c5740b6624ba50d3480176ed7239a22b465  1771884352
# 1  0x03fe8c5740b6624ba50d3480176ed7239a22b465  1771884334
# 2  0x03fe8c5740b6624ba50d3480176ed7239a22b465  1765634969
# 3  0x03fe8c5740b6624ba50d3480176ed7239a22b465  1765634969
# 4  0x03fe8c5740b6624ba50d3480176ed7239a22b465  1765634947
#
#                                          conditionId   type  size  usdcSize  \
# 0  0x43edd40756d4dfaa633687ddbfab445cdd21f9083a45...  TRADE  48.0   36.0000
# 1  0x797d586ad45522306490b0cc9b2f21bdf957f3843476...  TRADE  40.0   12.3959
# 2  0x63daae9d0fb558b5ea7264557ab2334d9d3866e0ab53...  TRADE  20.0    8.0000
# 3  0xd8a51600e6ec2641fcc25efea4f1ce32d00f0c665f52...  TRADE  20.0   11.2000
# 4  0x749581eca56770df39a0126af46418fe2b360df777dd...  TRADE  20.0    7.8000
#
#                                      transactionHash     price  \
# 0  0x7177705d88ebcb97390d04e9387d08b60dbe6480bbbe...  0.750000
# ...

# %%
len(df)
# Out:
# 100
