# %%
from datetime import datetime, timezone
from pathlib import Path

import pandas as pd

DATA_DIR = Path('/Users/yitongzheng/Documents/polymarket/apps/recording/data')

path = max(DATA_DIR.glob('trades_*.jsonl'), key=lambda p: p.stat().st_mtime)
df = pd.read_json(path, lines=True)
df.tail()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 8
#       4 import pandas as pd
#       6 DATA_DIR = Path('/Users/yitongzheng/Documents/polymarket/apps/recording/data')
# ----> 8 path = max(DATA_DIR.glob('trades_*.jsonl'), key=lambda p: p.stat().st_mtime)
#       9 print(path)
#      10 df = pd.read_json(path, lines=True)
#
# ValueError: max() iterable argument is empty

# %%
len(df)
# Out:
# 0
