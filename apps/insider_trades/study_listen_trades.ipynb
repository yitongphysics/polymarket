# %%
from datetime import datetime, timezone
from pathlib import Path

import pandas as pd

DATA_DIR = Path('/Users/yitongzheng/Documents/polymarket/apps/insider_trades/data')

path = max(DATA_DIR.glob('trades_*.jsonl'), key=lambda p: p.stat().st_mtime)
df = pd.read_json(path, lines=True)
df.tail()
# Out:
#              timestamp                                 proxyWallet  side  \
# 6  2026-04-27 02:27:00  0xe243070d11670abc32aac7125cb7abaf39a279f7  SELL
# 7  2026-04-27 02:27:00  0xe243070d11670abc32aac7125cb7abaf39a279f7  SELL
# 8  2026-04-27 02:27:00  0xe243070d11670abc32aac7125cb7abaf39a279f7  SELL
# 9  2026-04-27 02:27:00  0xe243070d11670abc32aac7125cb7abaf39a279f7  SELL
# 10 2026-04-27 02:27:00  0xe243070d11670abc32aac7125cb7abaf39a279f7  SELL
#
#    outcome  price   size                                               slug  \
# 6      Yes  0.029  53.17  will-donald-trump-win-the-2028-us-presidential...
# 7      Yes  0.029  53.17  will-donald-trump-win-the-2028-us-presidential...
# 8      Yes  0.029  53.17  will-donald-trump-win-the-2028-us-presidential...
# 9      Yes  0.029  53.17  will-donald-trump-win-the-2028-us-presidential...
# 10     Yes  0.029  53.17  will-donald-trump-win-the-2028-us-presidential...
#
#                                           conditionId  \
# ...

# %%
len(df)
# Out:
# 11
