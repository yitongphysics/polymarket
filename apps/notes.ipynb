# %%
import pandas as pd

# %%
file = '/Users/yitongzheng/Documents/polymarket/apps/recording/data/market_data_iran/iran_trades_wallet.jsonl'

df = pd.read_json(file, lines=True)

print(df.columns)
print(len(df))
# Out:
# Index(['timestamp', 'proxyWallet', 'side', 'outcome', 'price', 'size', 'slug',
#        'conditionId', 'transactionHash', 'market_question', 'market_slug'],
#       dtype='str')
# 1261

# %%
file = '/Users/yitongzheng/Documents/polymarket/apps/recording/data/market_data_iran/iran_trades.jsonl'

df = pd.read_json(file, lines=True)

print(df.columns)
print(len(df))
# Out:
# Index(['event_type', 'ts', 'observed_at', 'token_id', 'condition_id', 'slug',
#        'taker_side', 'price', 'size'],
#       dtype='str')
# 5

# %%
file = '/Users/yitongzheng/Documents/polymarket/apps/recording/data/market_data_iran/iran_updates.jsonl'

df = pd.read_json(file, lines=True)

print(df.columns)
print(len(df))
# Out:
# Index(['event_type', 'ts', 'observed_at', 'token_id', 'condition_id', 'slug',
#        'best_bid', 'best_ask', 'source'],
#       dtype='str')
# 569
