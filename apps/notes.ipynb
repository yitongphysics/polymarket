# %%
import pandas as pd

file = '/Users/yitongzheng/Documents/polymarket/apps/recording/data/market_trades_test.parquet'

df = pd.read_parquet(file)

# %%
df.groupby('conditionId').size().sort_values(ascending=False)
# Out:
# conditionId
# 0xceb6dfaa2cf5abc9d47ebc867b984a7715104944249274e8a483a2e17473e5f5    2541
# 0x9967297556e4fd7f7e1e688a2e44d6fdbc42b0700576a1e4e67aa37764ac640a    1569
# 0x518a5b030b205706b8ffe6bbad9bd3de59548348e5c0471827f5de21e513333c    1565
# 0xf9f0965a3bd704ad9c184851242606ad35a4ffe733febf5074d4fbcc59d52eb8     970
# 0x0e4a0c937b8934c2475613b6322b3f8edc8dedc24762e01e42b0e6f87424a089     956
#                                                                       ...
# 0x584c9773bd54965e7c1b4c7ca6dd6ec7a7ee47632f41f877be179aeb3c9006be       1
# 0x4266ab921148974f104cbadd099e13bca989441bf58acfd2a08fc6cc7440e1a1       1
# 0xb10aa376c96281d85f8d93e69107bb37aedb1bc2b953e24718836aee1bb64f3f       1
# 0x7d9928e23aefb2209696048829b614f49e387d5a77327aa887d0724952fd1156       1
# 0x549491140b9b057ecbc6606b0a7e15e860ae16c9778e95751291bdc9c13bfaa9       1
# Length: 167, dtype: int64

# %%
df.columns
# Out:
# Index(['timestamp', 'proxyWallet', 'side', 'outcome', 'price', 'size', 'slug',
#        'conditionId', 'transactionHash', 'market_question', 'market_slug'],
#       dtype='str')
